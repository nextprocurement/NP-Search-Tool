# %%
from pathlib import Path
import pandas as pd
import os
import re
import logging

# %%
import ast
import io
import itertools
import zipfile
from collections import Counter
from logging import Logger
from pathlib import Path
from typing import List, Union

import numpy as np
import pandas as pd
import regex


def fill_na(cell, fill=[]):
    """
    Fill elements in pd.DataFrame with `fill`.
    """
    if hasattr(cell, "__iter__"):
        if isinstance(cell, str):
            if cell == "nan":
                return fill
            return cell
        nas = [True if el == "nan" or pd.isna(el) else False for el in cell]
        if all(nas):
            return fill
        return cell
    if pd.isna(cell):
        return fill
    return cell


def process_lote(el):
    """ 
    Convert string representation of a list into a list. Used to process the columns 'ProcurementProjectLot.ProcurementProject.Name' and 'ProcurementProjectLot.ID'.

    Parameters
    ----------
    el : str
        String representation of a list.

    Returns
    -------
    el : list
        List of elements.
    """
    if pd.notna(el):
        try:
            aux = ast.literal_eval(el[0])
            if isinstance(aux, float):
                aux = [int(aux)]
            return aux
        except (SyntaxError, ValueError):
            return [el[0]]
    else:
        return el


def melt_two_series(s1, s2):
    """ 
    Melt two series into a DataFrame, expanding rows to match elements in the series, 
    effectively transforming a single row into multiple rows. This function is useful 
    when dealing with columns containing lists, such as 'ProcurementProjectLot.ProcurementProject.Name' 
    and 'ProcurementProjectLot.ID'. 

    Parameters
    ---------- 
    s1 : pd.Series
        First series to melt.
    s2 : pd.Series)
        Second series to melt.

    Returns
    -------
    pd.DataFrame: A DataFrame with melted series, with each row containing metadata from the original DataFrame but for each element in the series.

    Example
    -------
    >>> s1 = pd.Series([['A', 'B'], ['C'], ['D', 'E', 'F']])
    >>> s2 = pd.Series([1, 2, 3])
    >>> melt_two_series(s1, s2)
      lot_name  lot_id
    0        A       1
    1        B       1
    2        C       2
    3        D       3
    4        E       3
    5        F       3
    """
    lengths_s1 = s1.str.len().values

    flat_s1 = [i for i in itertools.chain.from_iterable(s1.values.tolist())]
    flat_s2 = [i for i in itertools.chain.from_iterable(s2.values.tolist())]

    idx_s1 = np.repeat(s1.index.values, lengths_s1)

    return pd.DataFrame({'lot_name': flat_s1, 'lot_id': flat_s2}, index=idx_s1)

# %%
dir_data = Path("/export/usuarios_ml4ds/lbartolome/NextProcurement/NP-Search-Tool/sample_data")
dir_text_metadata = Path("/export/usuarios_ml4ds/lbartolome/NextProcurement/NP-Search-Tool/test")

path_parquets = Path("/export/usuarios_ml4ds/lbartolome/NextProcurement/NP-Search-Tool/sample_data/all_processed")
path_place_without_lote_processed_title = path_parquets / "trf_lote_es.parquet"

path_metadata = Path("/export/usuarios_ml4ds/lbartolome/NextProcurement/NP-Search-Tool/sample_data/metadata")
path_in = path_metadata / "insiders.parquet"
path_out = path_metadata / "outsiders.parquet"
path_min = path_metadata / "minors.parquet"

# %% [markdown]
# ### READ PROCESSED DATA

# %%
processed = pd.read_parquet(path_place_without_lote_processed_title)
processed
# Out:
#                                                       id_tm
# identifier
# contratosMenoresPerfilesContratantes_2018.zip/c...        0  \
# contratosMenoresPerfilesContratantes_2018.zip/c...        1
# contratosMenoresPerfilesContratantes_2018.zip/c...        3
# contratosMenoresPerfilesContratantes_2018.zip/c...        4
# contratosMenoresPerfilesContratantes_2018.zip/c...        5
# ...                                                     ...
# PlataformasAgregadasSinMenores_202401.zip/Plata...  3110256
# PlataformasAgregadasSinMenores_202401.zip/Plata...  3110257
# PlataformasAgregadasSinMenores_202401.zip/Plata...  3110258
# PlataformasAgregadasSinMenores_202401.zip/Plata...  3110259
# PlataformasAgregadasSinMenores_202401.zip/Plata...  3110260
#
#                                                                                              raw_text
# identifier
# contratosMenoresPerfilesContratantes_2018.zip/c...  Reforma de elementos de ventilación exterior d...  \
# contratosMenoresPerfilesContratantes_2018.zip/c...  Servicios de calibrado y certificado de dos de...
# contratosMenoresPerfilesContratantes_2018.zip/c...  Redacción EPIA - Legalización antena emisora d...
# contratosMenoresPerfilesContratantes_2018.zip/c...  Obras de reparación del Centro de Información ...
# contratosMenoresPerfilesContratantes_2018.zip/c...  Diversos materiales para el acondicionamiento ...
# ...                                                                                               ...
# PlataformasAgregadasSinMenores_202401.zip/Plata...  concesion de servicios de peluquerías en 10 cp...
# PlataformasAgregadasSinMenores_202401.zip/Plata...  Servicios y suministros para la seguridad inte...
# PlataformasAgregadasSinMenores_202401.zip/Plata...  Contrato de concesión de servicios para la ges...
# PlataformasAgregadasSinMenores_202401.zip/Plata...  Investigación, validación, verificación y gest...
# PlataformasAgregadasSinMenores_202401.zip/Plata...  Proyecto Conducción Abast. desde ETAP Los Palm...
#
#                                                                                                lemmas
# identifier
# contratosMenoresPerfilesContratantes_2018.zip/c...  reforma elemento ventilación exterior aire_aco...
# contratosMenoresPerfilesContratantes_2018.zip/c...  calibrado certificado detector portátil gas tr...
# contratosMenoresPerfilesContratantes_2018.zip/c...      epia legalización antena emisora_radio narcea
# contratosMenoresPerfilesContratantes_2018.zip/c...              centro información naturaleza rellano
# contratosMenoresPerfilesContratantes_2018.zip/c...  rotonda arriat decoracion jardinera maceta via...
# ...                                                                                               ...
# PlataformasAgregadasSinMenores_202401.zip/Plata...                      concesion cpas dependiente dt
# PlataformasAgregadasSinMenores_202401.zip/Plata...                                    integral veiasa
# PlataformasAgregadasSinMenores_202401.zip/Plata...                             concesión integral cfa
# PlataformasAgregadasSinMenores_202401.zip/Plata...  validación verificación documental proyecto pacto
# PlataformasAgregadasSinMenores_202401.zip/Plata...                     conducción abast etap palmares
#
# [2637237 rows x 3 columns]

# %%
def merge_data(
    dir_data,
    dir_text_metadata,
    merge_dfs= ["minors", "insiders", "outsiders"],
    use_lot_info: bool = True,
    eliminate_duplicates: bool = True,
    logger = None,
):
    """
    Merge original data parquet files into single dataframe
    """
    dir_data = Path(dir_data)
    dfs = []
    origins = []

    if dir_data.suffix == ".zip":
        # If it's a zip file, create a zipfile.Path and find the specific folder within it.
        with zipfile.ZipFile(dir_data, "r") as zip_ref:
            all_files = zip_ref.namelist()
            for d in merge_dfs:
                file_path = f"metadata/{d}.parquet"
                if file_path in all_files:
                    pq_file = io.BytesIO(zip_ref.read(file_path))
                    dfs.append(pd.read_parquet(pq_file))
                    origins.append(d)
                elif logger:
                    logger.warning(
                        f"File {d}.parquet does not exist in the zip file, skipping."
                    )
                else:
                    continue
    else:
        # If it's a directory, create a Path and find the specific folder within it.
        for d in merge_dfs:
            file_path = dir_data.joinpath(f"metadata/{d}.parquet")
            logger.warning(f"File {file_path.as_posix()} does not exist, skipping.")
            if file_path.exists():
                dfs.append(pd.read_parquet(file_path))
                origins.append(d)
            elif logger:
                logger.warning(f"File {d}.parquet does not exist, skipping.")
            else:
                continue
    if not dfs:
        if logger:
            logger.error("No dataframes to merge.")
        return

    # Unify texts from all sources
    dfs_text = []
    for df, d in zip(dfs, origins):
        # Reset index and rename to common identifier: new index is generated as the concatenation of 'zip', 'file name', 'entry'
        index_names = df.index.names
        orig_cols = df.columns
        df.reset_index(inplace=True)
        df["identifier"] = df[index_names].astype(str).agg("/".join, axis=1)
        df.set_index("identifier", inplace=True)
        df = df[orig_cols]

        # Select text columns and rename them
        def join_str(x): return ".".join([el for el in x if el])
        joint_cnames = {join_str(c): c for c in df.columns}
        reverse_joint_cnames = {v: k for k, v in joint_cnames.items()}

        if not use_lot_info:
            cols_keep = ["title", "summary", "text", "origin"]
            cols_order = ["id_tm", "title", "summary", "text", "origin"]
            # If we don't want to use lot info, we only need to select the text columns 'summary' and 'title'
            text_cols = sorted(
                [
                    v for k, v in joint_cnames.items()
                    if "summary" in k or "title" in k
                ]
            )
            

            df_text = df.loc[:, text_cols]
            use_cols = [
                reverse_joint_cnames[c].split(".", 1)[-1]
                for c in text_cols
            ]
            df_text.columns = use_cols

            # Define columns that will be used as text
            columns_for_text = ["title", "summary"]
        else:
            print("USING LOT INFO")
            cols_keep = ["title", "summary", "lot_name", "text", "origin"]
            cols_order = ["id_tm", "title", "summary", "lot_name", "text", "origin"]
            
            # If we want to use lot info, we need to select the text columns 'summary' and 'title' and the columns 'ProcurementProjectLot.ProcurementProject.Name' and 'ProcurementProjectLot.ID'
            text_cols = sorted(
                [
                    v for k, v in joint_cnames.items()
                    if "summary" in k
                    or "title" in k
                    or "id" in k
                    or "ContractFolderStatus.ProcurementProjectLot.ProcurementProject.Name" in k
                    or "ContractFolderStatus.ProcurementProjectLot.ID" in k
                ]
            )

            df_text = df.loc[:, text_cols]
            use_cols = [
                reverse_joint_cnames[c].split(".", 1)[-1]
                for c in text_cols
            ]
            df_text.columns = use_cols

            if "ProcurementProjectLot.ID" in use_cols:

                # Rename columns for better readability
                rename_columns = {
                    "ProcurementProjectLot.ID": "lot_id",
                    "ProcurementProjectLot.ProcurementProject.Name": "lot_name",
                }
                df_text = df_text.rename(columns=rename_columns)

                # Convert columns 'lot_name' and 'lot_id' to lists
                df_text["lot_name"] = df_text["lot_name"].apply(process_lote)
                df_text["lot_id"] = df_text["lot_id"].apply(process_lote)

                # Melt the columns 'lot_name' and 'lot_id' into a single DataFrame
                df_text = melt_two_series(df_text['lot_name'], df_text['lot_id']).join(
                    df_text.drop(['lot_name', 'lot_id'], axis=1))

                # Set index to 'identifier' lost during melt
                df_text.index.names = ['identifier']

                # Redefine identifier to include lot_id if it exists
                orig_cols = ["title", "summary", "lot_name"]
                df_text.reset_index(inplace=True)
                df_text["identifier"] = df_text.apply(lambda row: '/'.join([str(row['identifier']), str(
                    row['lot_id'])]) if row['lot_id'] != "nan" else row['identifier'], axis=1)
                df_text.set_index("identifier", inplace=True)

                # Define columns that will be used as text
                columns_for_text = ["title", "summary", "lot_name"]#"id"
            else:
                rename_columns = {
                    "ContractFolderStatus.ProcurementProject.RequiredCommodityClassification.ItemClassificationCode": "cpv",
                }
                df_text = df_text.rename(columns=rename_columns)
                
                df_text["lot_name"] = len(df_text) * np.nan

        df_text["text"] = (
            df_text[columns_for_text]
            .applymap(fill_na, fill=None)
            .agg(lambda x: ". ".join([str(el) for el in x if el]), axis=1)
        )

        if eliminate_duplicates:
            df_text = df_text.drop_duplicates(subset=['text'])
        
        df_text["origin"] = [d] * len(df_text)

        dfs_text.append(df_text)

    # Concatenate and save as unique DataFrame-
    df_text = pd.concat(dfs_text)[cols_keep]
    if "lot_name" in cols_keep:
        mask = df_text['lot_name'].apply(lambda x: isinstance(x, int))
        df_text.loc[mask, 'lot_name'] = df_text.loc[mask, 'lot_name'].astype(str)
    dir_text_metadata.parent.mkdir(parents=True, exist_ok=True)
    df_text["id_tm"] = np.arange(len(df_text))
    df_text = df_text[cols_order]
    df_text.to_parquet(dir_text_metadata, engine="pyarrow")
    return df_text

# %%
logger = logging.Logger("test")
df = merge_data(dir_data, dir_text_metadata, use_lot_info = False, logger = logger)
# Out:
# File /export/usuarios_ml4ds/lbartolome/NextProcurement/NP-Search-Tool/sample_data/metadata/minors.parquet does not exist, skipping.
# File /export/usuarios_ml4ds/lbartolome/NextProcurement/NP-Search-Tool/sample_data/metadata/insiders.parquet does not exist, skipping.
# File /export/usuarios_ml4ds/lbartolome/NextProcurement/NP-Search-Tool/sample_data/metadata/outsiders.parquet does not exist, skipping.

# %%
df
# Out:
#                                                       id_tm
# identifier
# contratosMenoresPerfilesContratantes_2018.zip/c...        0  \
# contratosMenoresPerfilesContratantes_2018.zip/c...        1
# contratosMenoresPerfilesContratantes_2018.zip/c...        2
# contratosMenoresPerfilesContratantes_2018.zip/c...        3
# contratosMenoresPerfilesContratantes_2018.zip/c...        4
# ...                                                     ...
# PlataformasAgregadasSinMenores_202401.zip/Plata...  3110256
# PlataformasAgregadasSinMenores_202401.zip/Plata...  3110257
# PlataformasAgregadasSinMenores_202401.zip/Plata...  3110258
# PlataformasAgregadasSinMenores_202401.zip/Plata...  3110259
# PlataformasAgregadasSinMenores_202401.zip/Plata...  3110260
#
#                                                                                                 title
# identifier
# contratosMenoresPerfilesContratantes_2018.zip/c...  Reforma de elementos de ventilación exterior d...  \
# contratosMenoresPerfilesContratantes_2018.zip/c...  Servicios de calibrado y certificado de dos de...
# contratosMenoresPerfilesContratantes_2018.zip/c...    Patrocinio menor proyecto " Activitats C.I.N.E"
# contratosMenoresPerfilesContratantes_2018.zip/c...  Redacción EPIA - Legalización antena emisora d...
# contratosMenoresPerfilesContratantes_2018.zip/c...  Obras de reparación del Centro de Información ...
# ...                                                                                               ...
# PlataformasAgregadasSinMenores_202401.zip/Plata...  concesion de servicios de peluquerías en 10 cp...
# PlataformasAgregadasSinMenores_202401.zip/Plata...  Servicios y suministros para la seguridad inte...
# PlataformasAgregadasSinMenores_202401.zip/Plata...  Contrato de concesión de servicios para la ges...
# PlataformasAgregadasSinMenores_202401.zip/Plata...  Investigación, validación, verificación y gest...
# PlataformasAgregadasSinMenores_202401.zip/Plata...  Proyecto Conducción Abast. desde ETAP Los Palm...
#
#                                                                                               summary
# identifier
# contratosMenoresPerfilesContratantes_2018.zip/c...  Id licitación: 000103/2017-1069; Órgano de Con...  \
# contratosMenoresPerfilesContratantes_2018.zip/c...  Id licitación: 29-2017-II; Órgano de Contratac...
# contratosMenoresPerfilesContratantes_2018.zip/c...  Id licitación: 013-07-2018; Órgano de Contrata...
# contratosMenoresPerfilesContratantes_2018.zip/c...  Id licitación: CON/2017/51; Órgano de Contrata...
# contratosMenoresPerfilesContratantes_2018.zip/c...  Id licitación: 000047/2017-1069; Órgano de Con...
# ...                                                                                               ...
# PlataformasAgregadasSinMenores_202401.zip/Plata...  Id licitación: CONTR 2023 0000922771; Órgano d...
# PlataformasAgregadasSinMenores_202401.zip/Plata...  Id licitación: CR050-23-087B; Órgano de contra...
# PlataformasAgregadasSinMenores_202401.zip/Plata...  Id licitación: CONTR 2023 0001215494; Órgano d...
# PlataformasAgregadasSinMenores_202401.zip/Plata...  Id licitación: CONTR 2023 0001095699; Órgano d...
# PlataformasAgregadasSinMenores_202401.zip/Plata...  Id licitación: CONTR 2023 0000650582; Órgano d...
#
#                                                                                                  text
# identifier
# contratosMenoresPerfilesContratantes_2018.zip/c...  Reforma de elementos de ventilación exterior d...  \
# contratosMenoresPerfilesContratantes_2018.zip/c...  Servicios de calibrado y certificado de dos de...
# contratosMenoresPerfilesContratantes_2018.zip/c...  Patrocinio menor proyecto " Activitats C.I.N.E...
# contratosMenoresPerfilesContratantes_2018.zip/c...  Redacción EPIA - Legalización antena emisora d...
# contratosMenoresPerfilesContratantes_2018.zip/c...  Obras de reparación del Centro de Información ...
# ...                                                                                               ...
# PlataformasAgregadasSinMenores_202401.zip/Plata...  concesion de servicios de peluquerías en 10 cp...
# PlataformasAgregadasSinMenores_202401.zip/Plata...  Servicios y suministros para la seguridad inte...
# PlataformasAgregadasSinMenores_202401.zip/Plata...  Contrato de concesión de servicios para la ges...
# PlataformasAgregadasSinMenores_202401.zip/Plata...  Investigación, validación, verificación y gest...
# PlataformasAgregadasSinMenores_202401.zip/Plata...  Proyecto Conducción Abast. desde ETAP Los Palm...
#
#                                                        origin
# identifier
# contratosMenoresPerfilesContratantes_2018.zip/c...     minors
# contratosMenoresPerfilesContratantes_2018.zip/c...     minors
# contratosMenoresPerfilesContratantes_2018.zip/c...     minors
# contratosMenoresPerfilesContratantes_2018.zip/c...     minors
# contratosMenoresPerfilesContratantes_2018.zip/c...     minors
# ...                                                       ...
# PlataformasAgregadasSinMenores_202401.zip/Plata...  outsiders
# PlataformasAgregadasSinMenores_202401.zip/Plata...  outsiders
# PlataformasAgregadasSinMenores_202401.zip/Plata...  outsiders
# PlataformasAgregadasSinMenores_202401.zip/Plata...  outsiders
# PlataformasAgregadasSinMenores_202401.zip/Plata...  outsiders
#
# [3110261 rows x 5 columns]

# %%
processed_duplicates = processed[processed.duplicated(subset="raw_text")]

# %%
processed_duplicates
# Out:
#                                                       id_tm
# identifier
# contratosMenoresPerfilesContratantes_2018.zip/c...      366  \
# contratosMenoresPerfilesContratantes_2018.zip/c...      478
# contratosMenoresPerfilesContratantes_2018.zip/c...      483
# contratosMenoresPerfilesContratantes_2018.zip/c...      490
# contratosMenoresPerfilesContratantes_2018.zip/c...      503
# ...                                                     ...
# PlataformasAgregadasSinMenores_202401.zip/Plata...  3110182
# PlataformasAgregadasSinMenores_202401.zip/Plata...  3110188
# PlataformasAgregadasSinMenores_202401.zip/Plata...  3110248
# PlataformasAgregadasSinMenores_202401.zip/Plata...  3110257
# PlataformasAgregadasSinMenores_202401.zip/Plata...  3110258
#
#                                                                                              raw_text
# identifier
# contratosMenoresPerfilesContratantes_2018.zip/c...                               Mecanizado de piezas  \
# contratosMenoresPerfilesContratantes_2018.zip/c...                  Traslado y depósito de vehículos.
# contratosMenoresPerfilesContratantes_2018.zip/c...                  Traslado y depósito de vehículos.
# contratosMenoresPerfilesContratantes_2018.zip/c...                  Traslado y depósito de vehículos.
# contratosMenoresPerfilesContratantes_2018.zip/c...                  Traslado y depósito de vehículos.
# ...                                                                                               ...
# PlataformasAgregadasSinMenores_202401.zip/Plata...  Contrato privado de seguros de riesgos permane...
# PlataformasAgregadasSinMenores_202401.zip/Plata...  Suministro de licencias y los servicios de man...
# PlataformasAgregadasSinMenores_202401.zip/Plata...  Suministro de modificador de fricción en el co...
# PlataformasAgregadasSinMenores_202401.zip/Plata...  Servicios y suministros para la seguridad inte...
# PlataformasAgregadasSinMenores_202401.zip/Plata...  Contrato de concesión de servicios para la ges...
#
#                                                                                            lemmas
# identifier
# contratosMenoresPerfilesContratantes_2018.zip/c...                               mecanizado_pieza
# contratosMenoresPerfilesContratantes_2018.zip/c...                              traslado depósito
# contratosMenoresPerfilesContratantes_2018.zip/c...                              traslado depósito
# contratosMenoresPerfilesContratantes_2018.zip/c...                              traslado depósito
# contratosMenoresPerfilesContratantes_2018.zip/c...                              traslado depósito
# ...                                                                                           ...
# PlataformasAgregadasSinMenores_202401.zip/Plata...  privado seguro riesgo permanente ayuntamiento
# PlataformasAgregadasSinMenores_202401.zip/Plata...           aplicación_informático jira_software
# PlataformasAgregadasSinMenores_202401.zip/Plata...            modificador_fricción contacto metro
# PlataformasAgregadasSinMenores_202401.zip/Plata...                                integral veiasa
# PlataformasAgregadasSinMenores_202401.zip/Plata...                         concesión integral cfa
#
# [278351 rows x 3 columns]

# %%
processed_duplicates[0:50]
# Out:
#                                                     id_tm
# identifier
# contratosMenoresPerfilesContratantes_2018.zip/c...    366  \
# contratosMenoresPerfilesContratantes_2018.zip/c...    478
# contratosMenoresPerfilesContratantes_2018.zip/c...    483
# contratosMenoresPerfilesContratantes_2018.zip/c...    490
# contratosMenoresPerfilesContratantes_2018.zip/c...    503
# contratosMenoresPerfilesContratantes_2018.zip/c...    509
# contratosMenoresPerfilesContratantes_2018.zip/c...    666
# contratosMenoresPerfilesContratantes_2018.zip/c...    667
# contratosMenoresPerfilesContratantes_2018.zip/c...    668
# contratosMenoresPerfilesContratantes_2018.zip/c...    669
# contratosMenoresPerfilesContratantes_2018.zip/c...    671
# contratosMenoresPerfilesContratantes_2018.zip/c...    682
# contratosMenoresPerfilesContratantes_2018.zip/c...    684
# contratosMenoresPerfilesContratantes_2018.zip/c...    685
# contratosMenoresPerfilesContratantes_2018.zip/c...    686
# contratosMenoresPerfilesContratantes_2018.zip/c...    690
# contratosMenoresPerfilesContratantes_2018.zip/c...    691
# contratosMenoresPerfilesContratantes_2018.zip/c...    727
# contratosMenoresPerfilesContratantes_2018.zip/c...    738
# contratosMenoresPerfilesContratantes_2018.zip/c...    764
# contratosMenoresPerfilesContratantes_2018.zip/c...    780
# contratosMenoresPerfilesContratantes_2018.zip/c...    800
# contratosMenoresPerfilesContratantes_2018.zip/c...    801
# contratosMenoresPerfilesContratantes_2018.zip/c...    802
# contratosMenoresPerfilesContratantes_2018.zip/c...    803
# contratosMenoresPerfilesContratantes_2018.zip/c...    804
# contratosMenoresPerfilesContratantes_2018.zip/c...    805
# contratosMenoresPerfilesContratantes_2018.zip/c...    806
# contratosMenoresPerfilesContratantes_2018.zip/c...    807
# contratosMenoresPerfilesContratantes_2018.zip/c...    809
# contratosMenoresPerfilesContratantes_2018.zip/c...    810
# contratosMenoresPerfilesContratantes_2018.zip/c...    811
# contratosMenoresPerfilesContratantes_2018.zip/c...    812
# contratosMenoresPerfilesContratantes_2018.zip/c...    813
# contratosMenoresPerfilesContratantes_2018.zip/c...    814
# contratosMenoresPerfilesContratantes_2018.zip/c...    815
# contratosMenoresPerfilesContratantes_2018.zip/c...   1151
# contratosMenoresPerfilesContratantes_2018.zip/c...   1157
# contratosMenoresPerfilesContratantes_2018.zip/c...   1272
# contratosMenoresPerfilesContratantes_2018.zip/c...   1280
# contratosMenoresPerfilesContratantes_2018.zip/c...   1524
# contratosMenoresPerfilesContratantes_2018.zip/c...   1526
# contratosMenoresPerfilesContratantes_2018.zip/c...   1590
# contratosMenoresPerfilesContratantes_2018.zip/c...   1632
# contratosMenoresPerfilesContratantes_2018.zip/c...   1634
# contratosMenoresPerfilesContratantes_2018.zip/c...   1724
# contratosMenoresPerfilesContratantes_2018.zip/c...   1725
# contratosMenoresPerfilesContratantes_2018.zip/c...   1726
# contratosMenoresPerfilesContratantes_2018.zip/c...   1727
# contratosMenoresPerfilesContratantes_2018.zip/c...   1729
#
#                                                                                              raw_text
# identifier
# contratosMenoresPerfilesContratantes_2018.zip/c...                               Mecanizado de piezas  \
# contratosMenoresPerfilesContratantes_2018.zip/c...                  Traslado y depósito de vehículos.
# contratosMenoresPerfilesContratantes_2018.zip/c...                  Traslado y depósito de vehículos.
# contratosMenoresPerfilesContratantes_2018.zip/c...                  Traslado y depósito de vehículos.
# contratosMenoresPerfilesContratantes_2018.zip/c...                  Traslado y depósito de vehículos.
# contratosMenoresPerfilesContratantes_2018.zip/c...                  Traslado y depósito de vehículos.
# contratosMenoresPerfilesContratantes_2018.zip/c...  Material de papelería para establecimiento de ...
# contratosMenoresPerfilesContratantes_2018.zip/c...  Material de papelería para establecimiento de ...
# contratosMenoresPerfilesContratantes_2018.zip/c...  Material de papelería para establecimiento de ...
# contratosMenoresPerfilesContratantes_2018.zip/c...  Material de papelería para establecimiento de ...
# contratosMenoresPerfilesContratantes_2018.zip/c...  Material de papelería para establecimiento de ...
# contratosMenoresPerfilesContratantes_2018.zip/c...  Suministro pequeño material informático para l...
# contratosMenoresPerfilesContratantes_2018.zip/c...  Suministro pequeño material informático para l...
# contratosMenoresPerfilesContratantes_2018.zip/c...  Suministro pequeño material informático para l...
# contratosMenoresPerfilesContratantes_2018.zip/c...  Suministro pequeño material informático para l...
# contratosMenoresPerfilesContratantes_2018.zip/c...  Suministro material de oficina para la Sede So...
# contratosMenoresPerfilesContratantes_2018.zip/c...  Suministro material de oficina para la Sede So...
# contratosMenoresPerfilesContratantes_2018.zip/c...  Suministro materiales diversos de mantenimient...
# contratosMenoresPerfilesContratantes_2018.zip/c...  Reunión Directores Mercas organizada por MERCA...
# contratosMenoresPerfilesContratantes_2018.zip/c...  Servicios exteriores de mensajería para la Sed...
# contratosMenoresPerfilesContratantes_2018.zip/c...  Servicio de coordinación consejo de redacción ...
# contratosMenoresPerfilesContratantes_2018.zip/c...  Servicios de redacción para la revista Distrib...
# contratosMenoresPerfilesContratantes_2018.zip/c...  Servicios de redacción para la revista Distrib...
# contratosMenoresPerfilesContratantes_2018.zip/c...  Servicios de redacción para la revista Distrib...
# contratosMenoresPerfilesContratantes_2018.zip/c...  Servicios de redacción para la revista Distrib...
# contratosMenoresPerfilesContratantes_2018.zip/c...  Servicios de redacción para la revista Distrib...
# contratosMenoresPerfilesContratantes_2018.zip/c...  Servicios de redacción para la revista Distrib...
# contratosMenoresPerfilesContratantes_2018.zip/c...  Servicios de redacción para la revista Distrib...
# contratosMenoresPerfilesContratantes_2018.zip/c...  Servicios de redacción para la revista Distrib...
# contratosMenoresPerfilesContratantes_2018.zip/c...  Servicios de redacción para la revista Distrib...
# contratosMenoresPerfilesContratantes_2018.zip/c...  Servicios de redacción para la revista Distrib...
# contratosMenoresPerfilesContratantes_2018.zip/c...  Servicios de redacción para la revista Distrib...
# contratosMenoresPerfilesContratantes_2018.zip/c...  Servicios de redacción para la revista Distrib...
# contratosMenoresPerfilesContratantes_2018.zip/c...  Servicios de redacción para la revista Distrib...
# contratosMenoresPerfilesContratantes_2018.zip/c...  Servicios de redacción para la revista Distrib...
# contratosMenoresPerfilesContratantes_2018.zip/c...  Servicios de redacción para la revista Distrib...
# contratosMenoresPerfilesContratantes_2018.zip/c...       Unidad de malla tapon Perfix 4,1 CM x 4,8 CM
# contratosMenoresPerfilesContratantes_2018.zip/c...      Un sistema de drenaje Pico Soft Port 15X15 CM
# contratosMenoresPerfilesContratantes_2018.zip/c...  Adquisición de un equipo evaporador/concentrador.
# contratosMenoresPerfilesContratantes_2018.zip/c...                       Espacio en Portal de Empleo.
# contratosMenoresPerfilesContratantes_2018.zip/c...  Contratación del acceso a la información conte...
# contratosMenoresPerfilesContratantes_2018.zip/c...  Contratación del acceso a la información conte...
# contratosMenoresPerfilesContratantes_2018.zip/c...                  Gastos de organización escuela vo
# contratosMenoresPerfilesContratantes_2018.zip/c...                     Elaboración de informe técnico
# contratosMenoresPerfilesContratantes_2018.zip/c...                     Elaboración de informe técnico
# contratosMenoresPerfilesContratantes_2018.zip/c...  Mantenimiento de fotocopiadoras "72.4 RGLCAP" ...
# contratosMenoresPerfilesContratantes_2018.zip/c...  Mantenimiento de fotocopiadoras "72.4 RGLCAP" ...
# contratosMenoresPerfilesContratantes_2018.zip/c...  Mantenimiento de fotocopiadoras "72.4 RGLCAP" ...
# contratosMenoresPerfilesContratantes_2018.zip/c...  Mantenimiento de fotocopiadoras "72.4 RGLCAP" ...
# contratosMenoresPerfilesContratantes_2018.zip/c...  Mantenimiento de fotocopiadoras "72.4 RGLCAP" ...
#
#                                                                                                lemmas
# identifier
# contratosMenoresPerfilesContratantes_2018.zip/c...                                   mecanizado_pieza
# contratosMenoresPerfilesContratantes_2018.zip/c...                                  traslado depósito
# contratosMenoresPerfilesContratantes_2018.zip/c...                                  traslado depósito
# contratosMenoresPerfilesContratantes_2018.zip/c...                                  traslado depósito
# contratosMenoresPerfilesContratantes_2018.zip/c...                                  traslado depósito
# contratosMenoresPerfilesContratantes_2018.zip/c...                                  traslado depósito
# contratosMenoresPerfilesContratantes_2018.zip/c...       papelería establecimiento_mercafresh mercasa
# contratosMenoresPerfilesContratantes_2018.zip/c...       papelería establecimiento_mercafresh mercasa
# contratosMenoresPerfilesContratantes_2018.zip/c...       papelería establecimiento_mercafresh mercasa
# contratosMenoresPerfilesContratantes_2018.zip/c...       papelería establecimiento_mercafresh mercasa
# contratosMenoresPerfilesContratantes_2018.zip/c...       papelería establecimiento_mercafresh mercasa
# contratosMenoresPerfilesContratantes_2018.zip/c...           pequeño informático sede_central mercasa
# contratosMenoresPerfilesContratantes_2018.zip/c...           pequeño informático sede_central mercasa
# contratosMenoresPerfilesContratantes_2018.zip/c...           pequeño informático sede_central mercasa
# contratosMenoresPerfilesContratantes_2018.zip/c...           pequeño informático sede_central mercasa
# contratosMenoresPerfilesContratantes_2018.zip/c...                    suministrar sede social mercasa
# contratosMenoresPerfilesContratantes_2018.zip/c...                    suministrar sede social mercasa
# contratosMenoresPerfilesContratantes_2018.zip/c...                                   centro comercial
# contratosMenoresPerfilesContratantes_2018.zip/c...  reunión_directores mercas_organizado mercasa a...
# contratosMenoresPerfilesContratantes_2018.zip/c...           exterior mensajería sede_central mercasa
# contratosMenoresPerfilesContratantes_2018.zip/c...                revista_distribución consumo número
# contratosMenoresPerfilesContratantes_2018.zip/c...               revista_distribución consumo_mercasa
# contratosMenoresPerfilesContratantes_2018.zip/c...               revista_distribución consumo_mercasa
# contratosMenoresPerfilesContratantes_2018.zip/c...               revista_distribución consumo_mercasa
# contratosMenoresPerfilesContratantes_2018.zip/c...               revista_distribución consumo_mercasa
# contratosMenoresPerfilesContratantes_2018.zip/c...               revista_distribución consumo_mercasa
# contratosMenoresPerfilesContratantes_2018.zip/c...               revista_distribución consumo_mercasa
# contratosMenoresPerfilesContratantes_2018.zip/c...               revista_distribución consumo_mercasa
# contratosMenoresPerfilesContratantes_2018.zip/c...               revista_distribución consumo_mercasa
# contratosMenoresPerfilesContratantes_2018.zip/c...               revista_distribución consumo_mercasa
# contratosMenoresPerfilesContratantes_2018.zip/c...               revista_distribución consumo_mercasa
# contratosMenoresPerfilesContratantes_2018.zip/c...               revista_distribución consumo_mercasa
# contratosMenoresPerfilesContratantes_2018.zip/c...               revista_distribución consumo_mercasa
# contratosMenoresPerfilesContratantes_2018.zip/c...               revista_distribución consumo_mercasa
# contratosMenoresPerfilesContratantes_2018.zip/c...               revista_distribución consumo_mercasa
# contratosMenoresPerfilesContratantes_2018.zip/c...               revista_distribución consumo_mercasa
# contratosMenoresPerfilesContratantes_2018.zip/c...                        unidad tapon_perfix cm x cm
# contratosMenoresPerfilesContratantes_2018.zip/c...                          drenaje pico_soft port cm
# contratosMenoresPerfilesContratantes_2018.zip/c...                            evaporador_concentrador
# contratosMenoresPerfilesContratantes_2018.zip/c...                              espacio portal empleo
# contratosMenoresPerfilesContratantes_2018.zip/c...                                    acceso jurídico
# contratosMenoresPerfilesContratantes_2018.zip/c...                                    acceso jurídico
# contratosMenoresPerfilesContratantes_2018.zip/c...                                   gasto escuela vo
# contratosMenoresPerfilesContratantes_2018.zip/c...                                            informe
# contratosMenoresPerfilesContratantes_2018.zip/c...                                            informe
# contratosMenoresPerfilesContratantes_2018.zip/c...                               fotocopiadora_rglcap
# contratosMenoresPerfilesContratantes_2018.zip/c...                               fotocopiadora_rglcap
# contratosMenoresPerfilesContratantes_2018.zip/c...                               fotocopiadora_rglcap
# contratosMenoresPerfilesContratantes_2018.zip/c...                               fotocopiadora_rglcap
# contratosMenoresPerfilesContratantes_2018.zip/c...                               fotocopiadora_rglcap

# %%
checking = processed_duplicates.merge(df, how="left", on="id_tm")

# %%
checking[0:50]
# Out:
#     id_tm                                           raw_text
# 0     366                               Mecanizado de piezas  \
# 1     478                  Traslado y depósito de vehículos.
# 2     483                  Traslado y depósito de vehículos.
# 3     490                  Traslado y depósito de vehículos.
# 4     503                  Traslado y depósito de vehículos.
# 5     509                  Traslado y depósito de vehículos.
# 6     666  Material de papelería para establecimiento de ...
# 7     667  Material de papelería para establecimiento de ...
# 8     668  Material de papelería para establecimiento de ...
# 9     669  Material de papelería para establecimiento de ...
# 10    671  Material de papelería para establecimiento de ...
# 11    682  Suministro pequeño material informático para l...
# 12    684  Suministro pequeño material informático para l...
# 13    685  Suministro pequeño material informático para l...
# 14    686  Suministro pequeño material informático para l...
# 15    690  Suministro material de oficina para la Sede So...
# 16    691  Suministro material de oficina para la Sede So...
# 17    727  Suministro materiales diversos de mantenimient...
# 18    738  Reunión Directores Mercas organizada por MERCA...
# 19    764  Servicios exteriores de mensajería para la Sed...
# 20    780  Servicio de coordinación consejo de redacción ...
# 21    800  Servicios de redacción para la revista Distrib...
# 22    801  Servicios de redacción para la revista Distrib...
# 23    802  Servicios de redacción para la revista Distrib...
# 24    803  Servicios de redacción para la revista Distrib...
# 25    804  Servicios de redacción para la revista Distrib...
# 26    805  Servicios de redacción para la revista Distrib...
# 27    806  Servicios de redacción para la revista Distrib...
# 28    807  Servicios de redacción para la revista Distrib...
# 29    809  Servicios de redacción para la revista Distrib...
# 30    810  Servicios de redacción para la revista Distrib...
# 31    811  Servicios de redacción para la revista Distrib...
# 32    812  Servicios de redacción para la revista Distrib...
# 33    813  Servicios de redacción para la revista Distrib...
# 34    814  Servicios de redacción para la revista Distrib...
# 35    815  Servicios de redacción para la revista Distrib...
# 36   1151       Unidad de malla tapon Perfix 4,1 CM x 4,8 CM
# 37   1157      Un sistema de drenaje Pico Soft Port 15X15 CM
# 38   1272  Adquisición de un equipo evaporador/concentrador.
# 39   1280                       Espacio en Portal de Empleo.
# 40   1524  Contratación del acceso a la información conte...
# 41   1526  Contratación del acceso a la información conte...
# 42   1590                  Gastos de organización escuela vo
# 43   1632                     Elaboración de informe técnico
# 44   1634                     Elaboración de informe técnico
# 45   1724  Mantenimiento de fotocopiadoras "72.4 RGLCAP" ...
# 46   1725  Mantenimiento de fotocopiadoras "72.4 RGLCAP" ...
# 47   1726  Mantenimiento de fotocopiadoras "72.4 RGLCAP" ...
# 48   1727  Mantenimiento de fotocopiadoras "72.4 RGLCAP" ...
# 49   1729  Mantenimiento de fotocopiadoras "72.4 RGLCAP" ...
#
#                                                lemmas
# 0                                    mecanizado_pieza  \
# 1                                   traslado depósito
# 2                                   traslado depósito
# 3                                   traslado depósito
# 4                                   traslado depósito
# 5                                   traslado depósito
# 6        papelería establecimiento_mercafresh mercasa
# 7        papelería establecimiento_mercafresh mercasa
# 8        papelería establecimiento_mercafresh mercasa
# 9        papelería establecimiento_mercafresh mercasa
# 10       papelería establecimiento_mercafresh mercasa
# 11           pequeño informático sede_central mercasa
# 12           pequeño informático sede_central mercasa
# 13           pequeño informático sede_central mercasa
# 14           pequeño informático sede_central mercasa
# 15                    suministrar sede social mercasa
# 16                    suministrar sede social mercasa
# 17                                   centro comercial
# 18  reunión_directores mercas_organizado mercasa a...
# 19           exterior mensajería sede_central mercasa
# 20                revista_distribución consumo número
# 21               revista_distribución consumo_mercasa
# 22               revista_distribución consumo_mercasa
# 23               revista_distribución consumo_mercasa
# 24               revista_distribución consumo_mercasa
# 25               revista_distribución consumo_mercasa
# 26               revista_distribución consumo_mercasa
# 27               revista_distribución consumo_mercasa
# 28               revista_distribución consumo_mercasa
# 29               revista_distribución consumo_mercasa
# 30               revista_distribución consumo_mercasa
# 31               revista_distribución consumo_mercasa
# 32               revista_distribución consumo_mercasa
# 33               revista_distribución consumo_mercasa
# 34               revista_distribución consumo_mercasa
# 35               revista_distribución consumo_mercasa
# 36                        unidad tapon_perfix cm x cm
# 37                          drenaje pico_soft port cm
# 38                            evaporador_concentrador
# 39                              espacio portal empleo
# 40                                    acceso jurídico
# 41                                    acceso jurídico
# 42                                   gasto escuela vo
# 43                                            informe
# 44                                            informe
# 45                               fotocopiadora_rglcap
# 46                               fotocopiadora_rglcap
# 47                               fotocopiadora_rglcap
# 48                               fotocopiadora_rglcap
# 49                               fotocopiadora_rglcap
#
#                                                 title
# 0                                Mecanizado de piezas  \
# 1                   Traslado y depósito de vehículos.
# 2                   Traslado y depósito de vehículos.
# 3                   Traslado y depósito de vehículos.
# 4                   Traslado y depósito de vehículos.
# 5                   Traslado y depósito de vehículos.
# 6   Material de papelería para establecimiento de ...
# 7   Material de papelería para establecimiento de ...
# 8   Material de papelería para establecimiento de ...
# 9   Material de papelería para establecimiento de ...
# 10  Material de papelería para establecimiento de ...
# 11  Suministro pequeño material informático para l...
# 12  Suministro pequeño material informático para l...
# 13  Suministro pequeño material informático para l...
# 14  Suministro pequeño material informático para l...
# 15  Suministro material de oficina para la Sede So...
# 16  Suministro material de oficina para la Sede So...
# 17  Suministro materiales diversos de mantenimient...
# 18  Reunión Directores Mercas organizada por MERCA...
# 19  Servicios exteriores de mensajería para la Sed...
# 20  Servicio de coordinación consejo de redacción ...
# 21  Servicios de redacción para la revista Distrib...
# 22  Servicios de redacción para la revista Distrib...
# 23  Servicios de redacción para la revista Distrib...
# 24  Servicios de redacción para la revista Distrib...
# 25  Servicios de redacción para la revista Distrib...
# 26  Servicios de redacción para la revista Distrib...
# 27  Servicios de redacción para la revista Distrib...
# 28  Servicios de redacción para la revista Distrib...
# 29  Servicios de redacción para la revista Distrib...
# 30  Servicios de redacción para la revista Distrib...
# 31  Servicios de redacción para la revista Distrib...
# 32  Servicios de redacción para la revista Distrib...
# 33  Servicios de redacción para la revista Distrib...
# 34  Servicios de redacción para la revista Distrib...
# 35  Servicios de redacción para la revista Distrib...
# 36       Unidad de malla tapon Perfix 4,1 CM x 4,8 CM
# 37      Un sistema de drenaje Pico Soft Port 15X15 CM
# 38  Adquisición de un equipo evaporador/concentrador.
# 39                       Espacio en Portal de Empleo.
# 40  Contratación del acceso a la información conte...
# 41  Contratación del acceso a la información conte...
# 42                  Gastos de organización escuela vo
# 43                     Elaboración de informe técnico
# 44                     Elaboración de informe técnico
# 45  Mantenimiento de fotocopiadoras "72.4 RGLCAP" ...
# 46  Mantenimiento de fotocopiadoras "72.4 RGLCAP" ...
# 47  Mantenimiento de fotocopiadoras "72.4 RGLCAP" ...
# 48  Mantenimiento de fotocopiadoras "72.4 RGLCAP" ...
# 49  Mantenimiento de fotocopiadoras "72.4 RGLCAP" ...
#
#                                               summary
# 0   Id licitación: 324/17; Órgano de Contratación:...  \
# 1   Id licitación: LE-2017/49 CM SE; Órgano de Con...
# 2   Id licitación: LE-2017/50 CM SE; Órgano de Con...
# 3   Id licitación: LE-2017/51 CM SE; Órgano de Con...
# 4   Id licitación: LE-2017/53 CM SE; Órgano de Con...
# 5   Id licitación: LE-2017/55 CM SE; Órgano de Con...
# 6   Id licitación: 01/16 DE-2/7; Órgano de Contrat...
# 7   Id licitación: 01/16 DE-3/7; Órgano de Contrat...
# 8   Id licitación: 01/16 DE-4/7; Órgano de Contrat...
# 9   Id licitación: 01/16 DE-5/7; Órgano de Contrat...
# 10  Id licitación: 01/16 DE-6/7; Órgano de Contrat...
# 11  Id licitación: 01/16 SIS-3/6; Órgano de Contra...
# 12  Id licitación: 01/16 SIS-4/6; Órgano de Contra...
# 13  Id licitación: 01/16 SIS-6/6; Órgano de Contra...
# 14  Id licitación: 01/16 SIS-5/6; Órgano de Contra...
# 15  Id licitación: 01/16 SVG-3/4; Órgano de Contra...
# 16  Id licitación: 01/16 SVG-4/4; Órgano de Contra...
# 17  Id licitación: 03/16 CCG3-3/3; Órgano de Contr...
# 18  Id licitación: 03/16 DEO-5/5; Órgano de Contra...
# 19  Id licitación: 03/16 SVG-3/4; Órgano de Contra...
# 20  Id licitación: 04/16 CRI; Órgano de Contrataci...
# 21  Id licitación: 05/16 CRI-11/17; Órgano de Cont...
# 22  Id licitación: 05/16 CRI-12/17; Órgano de Cont...
# 23  Id licitación: 05/16 CRI-13/17; Órgano de Cont...
# 24  Id licitación: 05/16 CRI-14/17; Órgano de Cont...
# 25  Id licitación: 05/16 CRI-15/17; Órgano de Cont...
# 26  Id licitación: 05/16 CRI-16/17; Órgano de Cont...
# 27  Id licitación: 05/16 CRI-17/17; Órgano de Cont...
# 28  Id licitación: 05/16 CRI-2/17; Órgano de Contr...
# 29  Id licitación: 05/16 CRI-3/17; Órgano de Contr...
# 30  Id licitación: 05/16 CRI-4/17; Órgano de Contr...
# 31  Id licitación: 05/16 CRI-5/17; Órgano de Contr...
# 32  Id licitación: 05/16 CRI-6/17; Órgano de Contr...
# 33  Id licitación: 05/16 CRI-7/17; Órgano de Contr...
# 34  Id licitación: 05/16 CRI-8/17; Órgano de Contr...
# 35  Id licitación: 05/16 CRI-9/17; Órgano de Contr...
# 36  Id licitación: CM1097/17; Órgano de Contrataci...
# 37  Id licitación: CM1102/17; Órgano de Contrataci...
# 38  Id licitación: 010017C20028; Órgano de Contrat...
# 39  Id licitación: EXP1706/02; Órgano de Contratac...
# 40  Id licitación: 47-2/2017/CJCCV; Órgano de Cont...
# 41  Id licitación: 47-3/2017/CJCCV; Órgano de Cont...
# 42  Id licitación: 500087277099; Órgano de Contrat...
# 43  Id licitación: 0042000663; Órgano de Contratac...
# 44  Id licitación: 0042000664; Órgano de Contratac...
# 45  Id licitación: T05/PGG-01/17/1-07; Órgano de C...
# 46  Id licitación: T05/PGG-01/17/2-05; Órgano de C...
# 47  Id licitación: T05/PGG-01/17/2-06; Órgano de C...
# 48  Id licitación: T05/PGG-01/17/3-04; Órgano de C...
# 49  Id licitación: T05/PGG-01/17/3-05; Órgano de C...
#
#                                                  text  origin
# 0   Mecanizado de piezas. Id licitación: 324/17; Ó...  minors
# 1   Traslado y depósito de vehículos.. Id licitaci...  minors
# 2   Traslado y depósito de vehículos.. Id licitaci...  minors
# 3   Traslado y depósito de vehículos.. Id licitaci...  minors
# 4   Traslado y depósito de vehículos.. Id licitaci...  minors
# 5   Traslado y depósito de vehículos.. Id licitaci...  minors
# 6   Material de papelería para establecimiento de ...  minors
# 7   Material de papelería para establecimiento de ...  minors
# 8   Material de papelería para establecimiento de ...  minors
# 9   Material de papelería para establecimiento de ...  minors
# 10  Material de papelería para establecimiento de ...  minors
# 11  Suministro pequeño material informático para l...  minors
# 12  Suministro pequeño material informático para l...  minors
# 13  Suministro pequeño material informático para l...  minors
# 14  Suministro pequeño material informático para l...  minors
# 15  Suministro material de oficina para la Sede So...  minors
# 16  Suministro material de oficina para la Sede So...  minors
# 17  Suministro materiales diversos de mantenimient...  minors
# 18  Reunión Directores Mercas organizada por MERCA...  minors
# 19  Servicios exteriores de mensajería para la Sed...  minors
# 20  Servicio de coordinación consejo de redacción ...  minors
# 21  Servicios de redacción para la revista Distrib...  minors
# 22  Servicios de redacción para la revista Distrib...  minors
# 23  Servicios de redacción para la revista Distrib...  minors
# 24  Servicios de redacción para la revista Distrib...  minors
# 25  Servicios de redacción para la revista Distrib...  minors
# 26  Servicios de redacción para la revista Distrib...  minors
# 27  Servicios de redacción para la revista Distrib...  minors
# 28  Servicios de redacción para la revista Distrib...  minors
# 29  Servicios de redacción para la revista Distrib...  minors
# 30  Servicios de redacción para la revista Distrib...  minors
# 31  Servicios de redacción para la revista Distrib...  minors
# 32  Servicios de redacción para la revista Distrib...  minors
# 33  Servicios de redacción para la revista Distrib...  minors
# 34  Servicios de redacción para la revista Distrib...  minors
# 35  Servicios de redacción para la revista Distrib...  minors
# 36  Unidad de malla tapon Perfix 4,1 CM x 4,8 CM. ...  minors
# 37  Un sistema de drenaje Pico Soft Port 15X15 CM....  minors
# 38  Adquisición de un equipo evaporador/concentrad...  minors
# 39  Espacio en Portal de Empleo.. Id licitación: E...  minors
# 40  Contratación del acceso a la información conte...  minors
# 41  Contratación del acceso a la información conte...  minors
# 42  Gastos de organización escuela vo. Id licitaci...  minors
# 43  Elaboración de informe técnico. Id licitación:...  minors
# 44  Elaboración de informe técnico. Id licitación:...  minors
# 45  Mantenimiento de fotocopiadoras "72.4 RGLCAP" ...  minors
# 46  Mantenimiento de fotocopiadoras "72.4 RGLCAP" ...  minors
# 47  Mantenimiento de fotocopiadoras "72.4 RGLCAP" ...  minors
# 48  Mantenimiento de fotocopiadoras "72.4 RGLCAP" ...  minors
# 49  Mantenimiento de fotocopiadoras "72.4 RGLCAP" ...  minors

# %% [markdown]
# #### Ahora con lot info

# %%
df = merge_data(dir_data, dir_text_metadata, use_lot_info = True, logger = logger)
# Out:
# File /export/usuarios_ml4ds/lbartolome/NextProcurement/NP-Search-Tool/sample_data/metadata/minors.parquet does not exist, skipping.
# File /export/usuarios_ml4ds/lbartolome/NextProcurement/NP-Search-Tool/sample_data/metadata/insiders.parquet does not exist, skipping.
# File /export/usuarios_ml4ds/lbartolome/NextProcurement/NP-Search-Tool/sample_data/metadata/outsiders.parquet does not exist, skipping.
# USING LOT INFO
# USING LOT INFO
# USING LOT INFO

# %%
df
# Out:
#                                                       id_tm
# identifier
# contratosMenoresPerfilesContratantes_2018.zip/c...        0  \
# contratosMenoresPerfilesContratantes_2018.zip/c...        1
# contratosMenoresPerfilesContratantes_2018.zip/c...        2
# contratosMenoresPerfilesContratantes_2018.zip/c...        3
# contratosMenoresPerfilesContratantes_2018.zip/c...        4
# ...                                                     ...
# PlataformasAgregadasSinMenores_202401.zip/Plata...  3360668
# PlataformasAgregadasSinMenores_202401.zip/Plata...  3360669
# PlataformasAgregadasSinMenores_202401.zip/Plata...  3360670
# PlataformasAgregadasSinMenores_202401.zip/Plata...  3360671
# PlataformasAgregadasSinMenores_202401.zip/Plata...  3360672
#
#                                                                                                 title
# identifier
# contratosMenoresPerfilesContratantes_2018.zip/c...  Actuacion de desmontado de cubierta de placas ...  \
# contratosMenoresPerfilesContratantes_2018.zip/c...  Servicio de mantenimiento de una puerta girato...
# contratosMenoresPerfilesContratantes_2018.zip/c...  Servivios tecnologia GESTIONA: suscripcion man...
# contratosMenoresPerfilesContratantes_2018.zip/c...  Suministro de equipos de sobremesa, portátiles...
# contratosMenoresPerfilesContratantes_2018.zip/c...  Realización de backup remoto en las oficinas d...
# ...                                                                                               ...
# PlataformasAgregadasSinMenores_202401.zip/Plata...  servicio de punto de encuentro familiar en la ...
# PlataformasAgregadasSinMenores_202401.zip/Plata...  0001181/2023 contr 2023 1204117 servicio de ma...
# PlataformasAgregadasSinMenores_202401.zip/Plata...  renting vehiculo 5 plazas para el delegado t. ...
# PlataformasAgregadasSinMenores_202401.zip/Plata...  Servicio de Asistencia Técnica y Auditorias In...
# PlataformasAgregadasSinMenores_202401.zip/Plata...  Obras de consolidación de la Muralla Sur entre...
#
#                                                                                               summary
# identifier
# contratosMenoresPerfilesContratantes_2018.zip/c...  Id licitación: 2.18/32619.5069/01; Órgano de C...  \
# contratosMenoresPerfilesContratantes_2018.zip/c...  Id licitación: 37/CM-02/19; Órgano de Contrata...
# contratosMenoresPerfilesContratantes_2018.zip/c...  Id licitación: FTRA-0254/2018; Órgano de Contr...
# contratosMenoresPerfilesContratantes_2018.zip/c...  Id licitación: 18.115.GS999.AI.01; Órgano de C...
# contratosMenoresPerfilesContratantes_2018.zip/c...  Id licitación: 18.114.GS999.AI.01; Órgano de C...
# ...                                                                                               ...
# PlataformasAgregadasSinMenores_202401.zip/Plata...  Id licitación: CONTR 2023 0000927905; Órgano d...
# PlataformasAgregadasSinMenores_202401.zip/Plata...  Id licitación: +6.65MUHQ7; Órgano de contratac...
# PlataformasAgregadasSinMenores_202401.zip/Plata...  Id licitación: CONTR 2023 0001053296; Órgano d...
# PlataformasAgregadasSinMenores_202401.zip/Plata...  Id licitación: 23/084; Órgano de Contratación...
# PlataformasAgregadasSinMenores_202401.zip/Plata...  Id licitación: 23/M-22.1; Órgano de Contratac...
#
#                                                                                              lot_name
# identifier
# contratosMenoresPerfilesContratantes_2018.zip/c...                                                nan  \
# contratosMenoresPerfilesContratantes_2018.zip/c...                                                nan
# contratosMenoresPerfilesContratantes_2018.zip/c...                                                nan
# contratosMenoresPerfilesContratantes_2018.zip/c...                                                nan
# contratosMenoresPerfilesContratantes_2018.zip/c...                                                nan
# ...                                                                                               ...
# PlataformasAgregadasSinMenores_202401.zip/Plata...                                                nan
# PlataformasAgregadasSinMenores_202401.zip/Plata...  Mantenimiento y reparación de sistemas para pr...
# PlataformasAgregadasSinMenores_202401.zip/Plata...                                                nan
# PlataformasAgregadasSinMenores_202401.zip/Plata...                                                nan
# PlataformasAgregadasSinMenores_202401.zip/Plata...                                                nan
#
#                                                                                                  text
# identifier
# contratosMenoresPerfilesContratantes_2018.zip/c...  Actuacion de desmontado de cubierta de placas ...  \
# contratosMenoresPerfilesContratantes_2018.zip/c...  Servicio de mantenimiento de una puerta girato...
# contratosMenoresPerfilesContratantes_2018.zip/c...  Servivios tecnologia GESTIONA: suscripcion man...
# contratosMenoresPerfilesContratantes_2018.zip/c...  Suministro de equipos de sobremesa, portátiles...
# contratosMenoresPerfilesContratantes_2018.zip/c...  Realización de backup remoto en las oficinas d...
# ...                                                                                               ...
# PlataformasAgregadasSinMenores_202401.zip/Plata...  servicio de punto de encuentro familiar en la ...
# PlataformasAgregadasSinMenores_202401.zip/Plata...  0001181/2023 contr 2023 1204117 servicio de ma...
# PlataformasAgregadasSinMenores_202401.zip/Plata...  renting vehiculo 5 plazas para el delegado t. ...
# PlataformasAgregadasSinMenores_202401.zip/Plata...  Servicio de Asistencia Técnica y Auditorias In...
# PlataformasAgregadasSinMenores_202401.zip/Plata...  Obras de consolidación de la Muralla Sur entre...
#
#                                                        origin
# identifier
# contratosMenoresPerfilesContratantes_2018.zip/c...     minors
# contratosMenoresPerfilesContratantes_2018.zip/c...     minors
# contratosMenoresPerfilesContratantes_2018.zip/c...     minors
# contratosMenoresPerfilesContratantes_2018.zip/c...     minors
# contratosMenoresPerfilesContratantes_2018.zip/c...     minors
# ...                                                       ...
# PlataformasAgregadasSinMenores_202401.zip/Plata...  outsiders
# PlataformasAgregadasSinMenores_202401.zip/Plata...  outsiders
# PlataformasAgregadasSinMenores_202401.zip/Plata...  outsiders
# PlataformasAgregadasSinMenores_202401.zip/Plata...  outsiders
# PlataformasAgregadasSinMenores_202401.zip/Plata...  outsiders
#
# [3360673 rows x 6 columns]
