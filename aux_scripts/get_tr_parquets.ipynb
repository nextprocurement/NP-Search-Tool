# %%
import pathlib
import pandas as pd
import os
import re

# %%
path_parquets = pathlib.Path("/export/usuarios_ml4ds/lbartolome/NextProcurement/NP-Search-Tool/sample_data/all_processed")
path_place_with_lote = path_parquets / "minors_insiders_outsiders_origen_con_lot_info.parquet"
path_place_without_lote = path_parquets / "minors_insiders_outsiders_origen_sin_lot_info.parquet"
path_place_processed_1 = path_parquets / "md.parquet"
path_place_processed_2 = path_parquets / "md2.parquet"
path_save = pathlib.Path("/export/usuarios_ml4ds/lbartolome/NextProcurement/NP-Search-Tool/sample_data/processed/minors_insiders_outsiders.parquet")

# %% [markdown]
# ### PROCESSED DATA

# %%
processed = pd.read_parquet(path_place_processed_2)
processed
# Out:
#                                                       id_tm
# identifier
# contratosMenoresPerfilesContratantes_2018.zip/c...        0  \
# contratosMenoresPerfilesContratantes_2018.zip/c...        1
# contratosMenoresPerfilesContratantes_2018.zip/c...        2
# contratosMenoresPerfilesContratantes_2018.zip/c...        3
# contratosMenoresPerfilesContratantes_2018.zip/c...        4
# ...                                                     ...
# PlataformasAgregadasSinMenores_202401.zip/Plata...  3360668
# PlataformasAgregadasSinMenores_202401.zip/Plata...  3360669
# PlataformasAgregadasSinMenores_202401.zip/Plata...  3360670
# PlataformasAgregadasSinMenores_202401.zip/Plata...  3360671
# PlataformasAgregadasSinMenores_202401.zip/Plata...  3360672
#
#                                                                                              raw_text
# identifier
# contratosMenoresPerfilesContratantes_2018.zip/c...  Actuacion de desmontado de cubierta de placas ...  \
# ...

# %% [markdown]
# ### Filter manual stopwords

# %%
path_manual_stops = "/export/usuarios_ml4ds/lbartolome/NextProcurement/NP-Search-Tool/sample_data/stopwords"

# %%
# Cargar todas las stopwords desde los archivos
stopwords = set()
for archivo in os.listdir(path_manual_stops):
    if archivo.endswith('.txt'):
        ruta_completa = os.path.join(path_manual_stops, archivo)
        with open(ruta_completa, 'r', encoding='utf-8') as f:
            stopwords.update(f.read().splitlines())

# Vectorizar el proceso de eliminación de stopwords
def eliminar_stopwords(fila):
    return ' '.join([palabra for palabra in fila.split() if palabra not in stopwords])

# Aplicar la función de processed vectorizada
processed['lemmas'] = processed['lemmas'].apply(eliminar_stopwords)
processed
# Out:
#                                                       id_tm
# identifier
# contratosMenoresPerfilesContratantes_2018.zip/c...        0  \
# contratosMenoresPerfilesContratantes_2018.zip/c...        1
# contratosMenoresPerfilesContratantes_2018.zip/c...        2
# contratosMenoresPerfilesContratantes_2018.zip/c...        3
# contratosMenoresPerfilesContratantes_2018.zip/c...        4
# ...                                                     ...
# PlataformasAgregadasSinMenores_202401.zip/Plata...  3360668
# PlataformasAgregadasSinMenores_202401.zip/Plata...  3360669
# PlataformasAgregadasSinMenores_202401.zip/Plata...  3360670
# PlataformasAgregadasSinMenores_202401.zip/Plata...  3360671
# PlataformasAgregadasSinMenores_202401.zip/Plata...  3360672
#
#                                                                                              raw_text
# identifier
# contratosMenoresPerfilesContratantes_2018.zip/c...  Actuacion de desmontado de cubierta de placas ...  \
# ...

# %% [markdown]
# ### PLACE WITH LOT INFORMATION

# %%
place_with_lote = pd.read_parquet(path_place_with_lote)
place_with_lote
# Out:
#                                                       id_tm
# identifier
# contratosMenoresPerfilesContratantes_2018.zip/c...        0  \
# contratosMenoresPerfilesContratantes_2018.zip/c...        1
# contratosMenoresPerfilesContratantes_2018.zip/c...        2
# contratosMenoresPerfilesContratantes_2018.zip/c...        3
# contratosMenoresPerfilesContratantes_2018.zip/c...        4
# ...                                                     ...
# PlataformasAgregadasSinMenores_202401.zip/Plata...  3360668
# PlataformasAgregadasSinMenores_202401.zip/Plata...  3360669
# PlataformasAgregadasSinMenores_202401.zip/Plata...  3360670
# PlataformasAgregadasSinMenores_202401.zip/Plata...  3360671
# PlataformasAgregadasSinMenores_202401.zip/Plata...  3360672
#
#                                                                                                 title
# identifier
# contratosMenoresPerfilesContratantes_2018.zip/c...  Reforma de elementos de ventilación exterior d...  \
# ...

# %%
place_with_lote = pd.merge(processed,place_with_lote,how='left', on='id_tm')
place_with_lote
# Out:
#            id_tm                                           raw_text
# 0              0  Actuacion de desmontado de cubierta de placas ...  \
# 1              1  Servicio de mantenimiento de una puerta girato...
# 2              2  Servivios tecnologia GESTIONA: suscripcion man...
# 3              3  Suministro de equipos de sobremesa, portátiles...
# 4              4  Realización de backup remoto en las oficinas d...
# ...          ...                                                ...
# 3360668  3360668  servicio de punto de encuentro familiar en la ...
# 3360669  3360669  0001181/2023 contr 2023 1204117 servicio de ma...
# 3360670  3360670  renting vehiculo 5 plazas para el delegado t. ...
# 3360671  3360671  Servicio de Asistencia Técnica y Auditorias In...
# 3360672  3360672  Obras de consolidación de la Muralla Sur entre...
#
#                                                     lemmas
# 0        actuacion desmontado cubierta placa_fibrocemen...  \
# ...

# %%
place_with_lote_minors = place_with_lote[place_with_lote.origin == "minors"]
place_with_lote_minors
# Out:
#            id_tm                                           raw_text
# 0              0  Actuacion de desmontado de cubierta de placas ...  \
# 1              1  Servicio de mantenimiento de una puerta girato...
# 2              2  Servivios tecnologia GESTIONA: suscripcion man...
# 3              3  Suministro de equipos de sobremesa, portátiles...
# 4              4  Realización de backup remoto en las oficinas d...
# ...          ...                                                ...
# 2167957  2167957  CM 11/2024 Mantenimiento microtomo del servici...
# 2167958  2167958  prestación de los servicios de soporte y mante...
# 2167959  2167959  Campaña  de publicidad institucional de Comuni...
# 2167960  2167960  Lote alimentos como atención protocolaria para...
# 2167961  2167961  Suministro de calorímetro de morteros. Id lici...
#
#                                                     lemmas
# 0            actuacion desmontado placa_fibrocemento osuna  \
# ...

# %%
place_with_lote_outsiders = place_with_lote[place_with_lote.origin == "outsiders"]
place_with_lote_outsiders
# Out:
#            id_tm                                           raw_text
# 3062741  3062741  Suministro 25 localizadores fugas. Id licitaci...  \
# 3062742  3062742  Servicios de informatización de la Unidad de C...
# 3062743  3062743  asesoramiento y asistencia a la Dirección Gene...
# 3062744  3062744  Servicio para la elaboración de los estudios p...
# 3062745  3062745  Suministro de cuatro (4) equipos de corte, sep...
# ...          ...                                                ...
# 3360668  3360668  servicio de punto de encuentro familiar en la ...
# 3360669  3360669  0001181/2023 contr 2023 1204117 servicio de ma...
# 3360670  3360670  renting vehiculo 5 plazas para el delegado t. ...
# 3360671  3360671  Servicio de Asistencia Técnica y Auditorias In...
# 3360672  3360672  Obras de consolidación de la Muralla Sur entre...
#
#                                                     lemmas
# 3062741             localizador_fuga consejo_adminsitación  \
# ...

# %%
place_with_lote_insiders = place_with_lote[place_with_lote.origin == "insiders"]
place_with_lote_insiders
# Out:
#            id_tm                                           raw_text
# 2167962  2167962  Ampliación de departamentos de usuarios de la ...  \
# 2167963  2167963  Atraque Ro-Ro en los Muelles Príncipe Felipe e...
# 2167964  2167964  Suministro de gas natural para el edificio sed...
# 2167965  2167965  Servicio de dirección, control y vigilancia de...
# 2167966  2167966  Servicio de limpieza general y retirada de res...
# ...          ...                                                ...
# 3062736  3062736  Limpieza y auxiliares de los edificios adscrit...
# 3062737  3062737  Contrato de servizos de redacción documentació...
# 3062738  3062738  Contrato de servicios de mantenimiento de los ...
# 3062739  3062739  Aprovechamiento cinegético del monte de la UP ...
# 3062740  3062740  Servicio de DDD y prevención y control de la l...
#
#                                                     lemmas
# 2167962                                              lonja  \
# ...

# %% [markdown]
# ### PLACE WITHOUT LOT INFORMATION

# %%
place_without_lote = pd.read_parquet(path_place_without_lote)
place_without_lote
# Out:
#                                                       id_tm     origen
# identifier
# contratosMenoresPerfilesContratantes_2018.zip/c...        0     minors  \
# contratosMenoresPerfilesContratantes_2018.zip/c...        1     minors
# contratosMenoresPerfilesContratantes_2018.zip/c...        2     minors
# contratosMenoresPerfilesContratantes_2018.zip/c...        3     minors
# contratosMenoresPerfilesContratantes_2018.zip/c...        4     minors
# ...                                                     ...        ...
# PlataformasAgregadasSinMenores_202401.zip/Plata...  3110256  outsiders
# PlataformasAgregadasSinMenores_202401.zip/Plata...  3110257  outsiders
# PlataformasAgregadasSinMenores_202401.zip/Plata...  3110258  outsiders
# PlataformasAgregadasSinMenores_202401.zip/Plata...  3110259  outsiders
# PlataformasAgregadasSinMenores_202401.zip/Plata...  3110260  outsiders
#
#                                                                                                 title
# ...

# %%
place_without_lote[~place_without_lote['origen'].isin(["minors", "insiders", "outsiders"])]
# Out:
# Empty DataFrame
# Columns: [id_tm, origen, title, summary, text]
# Index: []

# %%
processed = pd.read_parquet(path_place_processed_1)

# %%
merged_df = pd.merge(place_with_lote, processed, how='inner', on='id_tm')
merged_df[merged_df.origen == "minors"]
# Out:
#            id_tm  origen                                              title
# 0              0  minors  Reforma de elementos de ventilación exterior d...  \
# 1              1  minors  Servicios de calibrado y certificado de dos de...
# 2              2  minors    Patrocinio menor proyecto " Activitats C.I.N.E"
# 3              3  minors  Redacción EPIA - Legalización antena emisora d...
# 4              4  minors  Obras de reparación del Centro de Información ...
# ...          ...     ...                                                ...
# 2167957  2167957  minors                    Suministro de energía eléctrica
# 2167958  2167958  minors  Proyecto ejecucion instalacion fibra optica ed...
# 2167959  2167959  minors  Adquisición de frigorifico para la sala de téc...
# 2167960  2167960  minors  Cm/2023/0007  adquisición software gestión pre...
# 2167961  2167961  minors  Servicios de Otros (atencion sanitaria empleados)
#
# ...

# %% [markdown]
# ### Remove "Id licitación: Órgano de contratación"

# %%
path_processed = pathlib.Path("/export/usuarios_ml4ds/lbartolome/NextProcurement/NP-Search-Tool/sample_data/all_processed/md_sin_lote_es.parquet")
path_raw = pathlib.Path("/export/usuarios_ml4ds/lbartolome/NextProcurement/NP-Search-Tool/sample_data/all_processed/minors_insiders_outsiders_origen_sin_lot_info.parquet")
df = pd.read_parquet(path_processed)
df2 = pd.read_parquet(path_raw)
df = pd.merge(df,df2,how='left', on='id_tm')
df
# Out:
#            id_tm                                           raw_text
# 0              0  Reforma de elementos de ventilación exterior d...  \
# 1              1  Servicios de calibrado y certificado de dos de...
# 2              2  Patrocinio menor proyecto " Activitats C.I.N.E...
# 3              3  Redacción EPIA - Legalización antena emisora d...
# 4              4  Obras de reparación del Centro de Información ...
# ...          ...                                                ...
# 2944100  3110255  Contrato de servicios para la prestación del s...
# 2944101  3110256  concesion de servicios de peluquerías en 10 cp...
# 2944102  3110258  Contrato de concesión de servicios para la ges...
# 2944103  3110259  Investigación, validación, verificación y gest...
# 2944104  3110260  Proyecto Conducción Abast. desde ETAP Los Palm...
#
#                                                     lemmas lang     origen
# ...

# %%
pattern = r'Id licitación:.*?Órgano de Contratación:'
df['summary'] = df['summary'].str.replace(pattern, '', regex=True, flags=re.IGNORECASE)
df
# Out:
#            id_tm                                           raw_text
# 0              0  Reforma de elementos de ventilación exterior d...  \
# 1              1  Servicios de calibrado y certificado de dos de...
# 2              2  Patrocinio menor proyecto " Activitats C.I.N.E...
# 3              3  Redacción EPIA - Legalización antena emisora d...
# 4              4  Obras de reparación del Centro de Información ...
# ...          ...                                                ...
# 2944100  3110255  Contrato de servicios para la prestación del s...
# 2944101  3110256  concesion de servicios de peluquerías en 10 cp...
# 2944102  3110258  Contrato de concesión de servicios para la ges...
# 2944103  3110259  Investigación, validación, verificación y gest...
# 2944104  3110260  Proyecto Conducción Abast. desde ETAP Los Palm...
#
#                                                     lemmas lang     origen
# ...

# %%
df.to_parquet("/export/usuarios_ml4ds/lbartolome/NextProcurement/NP-Search-Tool/sample_data/all_processed/md_sin_lote_es_sin_org.parquet")

# %%
df["len"] = df['summary'].apply(len)

# %%
non_empty_rows = df['summary'].str.strip() != ''
non_empty_df = df[non_empty_rows]
print(f"There are {len(non_empty_df)} / {len(df)} after removing 'Id licitación:.*?Órgano de Contratación:'")
# Out:
# There are 2944105 / 2944105 after removing 'Id licitación:.*?Órgano de Contratación:'

# %%
3360673 - 2944105
# Out:
# 416568
